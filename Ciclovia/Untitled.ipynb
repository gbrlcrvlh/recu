# %%
# Author: Aric Hagberg (hagberg@lanl.gov)
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np 

G = nx.Graph()

G.add_edge('a', 'b', weight=0.6)
G.add_edge('a', 'c', weight=0.2)
G.add_edge('c', 'd', weight=0.1)
G.add_edge('c', 'e', weight=0.7)
G.add_edge('c', 'f', weight=0.9)
G.add_edge('a', 'd', weight=0.3)

elarge = [(u, v) for (u, v, d) in G.edges(data=True) if d['weight'] > 0.5]
esmall = [(u, v) for (u, v, d) in G.edges(data=True) if d['weight'] <= 0.5]

pos = nx.spring_layout(G)  # positions for all nodes

# nodes
nx.draw_networkx_nodes(G, pos, node_size=700)

# edges
nx.draw_networkx_edges(G, pos, edgelist=elarge,
                       width=6)
nx.draw_networkx_edges(G, pos, edgelist=esmall,
                       width=6, alpha=0.5, edge_color='b', style='dashed')

# labels
nx.draw_networkx_labels(G, pos, font_size=20, font_family='sans-serif')

plt.axis('off')
plt.show()

# %%
for e in elarge:
    print(pos[e[0]])
# Out:
# [0.41117204 0.54645655]
# [-0.23632981 -0.46656996]
# [-0.23632981 -0.46656996]

# %%
pos
# Out:
# {'a': array([0.41117204, 0.54645655]),
#  'b': array([0.94796499, 0.96510627]),
#  'c': array([-0.23632981, -0.46656996]),
#  'd': array([-0.29810041,  0.70647044]),
#  'e': array([-0.82680292, -0.7514633 ]),
#  'f': array([ 0.0020961, -1.       ])}

# %%
elarge
# Out:
# [('a', 'b'), ('c', 'e'), ('c', 'f')]

# %%
from geopy.geocoders import Nominatim

# %%
geolocator = Nominatim(user_agent="specify_your_app_name_here")
location = geolocator.reverse("2.8166433,-60.6735415")
print(location.raw['address']['suburb'])
# Out:
# Centro

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import requests

# %%
page = requests.get("http://populacao.net.br/os-maiores-bairros-boa-vista_rr.html")
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <link href="css-js/avatar_b1a417273446_128.png" rel="shortcut icon"/>
#   <link href="css-js/benvoliotheme_1.0.css" rel="stylesheet" type="text/css"/>
#   <link href="http://fonts.googleapis.com/css?family=Sintony:400,700" rel="stylesheet" type="text/css"/>
#   <!--[if lte IE 8]>
#     <script src="css-js/html5.js" type="text/javascript"></script>
#     <link rel="stylesheet" type="text/css" href="css-js/benvoliotheme_ie_1.0.css">
# <![endif]-->
#   <!--Load the AJAX API-->
#   <script src="https://www.google.com/jsapi" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    google.load('visualization', '1.0', {'packages': ['corechart']});
#   </script>
#   <!-- JAVACSCRIPT : begin -->
#   <script src="css-js/jquery-1.8.2.min.js" type="text/javascript">
#   </script>
#   <script src="css-js/pa_modernizr_1.0.js" type="text/javascript">
#   </script>
#   <script src="css-js/benvoliotheme_1.0.js" type="text/javascript">
#   </script>
#   <script src="css-js/select2/select2.js">
#   </script>
#   <link href="css-js/select2/select2.css" rel="stylesheet" type="text/css">
#    <link href="css-js/select2/select2-bootstrap.css" rel="stylesheet" type="text/css">
#     <script>
#      $(document).ready(function() {
#         $('.select2').select2();
#     });
#     </script>
#     <script src="css-js/jquery.quicksearch.js">
#     </script>
#     <script>
#      $(function() {
#         $(".tag_cloud_cidade").each(function() {
#             $input = $(this).find('input[type=text]');
#             $ul = $(this).find('ul li');
#             $input.quicksearch($ul);
#         });
#     });
#     </script>
#     <script>
#      (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-44983393-1', 'populacao.net.br');
#   ga('send', 'pageview');
#     </script>
#     <title>
#      Os maiores bairros de Boa Vista - Roraima | Lista dos 10 maiores bairros de Boa Vista
#     </title>
#     <meta content="Lista dos 10 maiores bairros de Boa Vista - Roraima. Saiba qual é o maior bairro de Boa Vista, entenda como está distribuida a população entre os maiores bairros de Boa Vista." name="description">
#      <link href="http://populacao.net.br/os-maiores-bairros-boa-vista_rr.html" rel="canonical">
#      </link>
#     </meta>
#    </link>
#   </link>
#  </head>
#  <body class="permalinkpage">
#   <div id="header-section">
#    <header>
#     <div class="container">
#      <div class="clearfix">
#       <a class="logo" href="index.php">
#        População
#       </a>
#       <div class="title">
#        <span>
#         o maior portal sobre população brasileira
#        </span>
#       </div>
#       <ul class="share">
#        <li class="btn-facebook">
#         <div id="fb-root">
#         </div>
#         <script>
#          (function(d, s, id) {
#                 var js, fjs = d.getElementsByTagName(s)[0];
#                 if (d.getElementById(id))
#                     return;
#                 js = d.createElement(s);
#                 js.id = id;
#                 js.src = "//connect.facebook.net/pt_BR/all.js#xfbml=1";
#                 fjs.parentNode.insertBefore(js, fjs);
#             }(document, 'script', 'facebook-jssdk'));
#         </script>
#         <div class="fb-like" data-action="like" data-colorscheme="light" data-href="http://populacao.net.br/os-maiores-bairros-boa-vista_rr.html" data-layout="button_count" data-send="false" data-show-faces="true">
#         </div>
#        </li>
#        <li class="btn-googleplus">
#         <!-- Posicione esta tag onde você deseja que o botão +1 apareça. -->
#         <div class="g-plusone" data-size="medium">
#         </div>
#         <!-- Posicione esta tag depois da última tag do botão +1. -->
#         <script type="text/javascript">
#          window.___gcfg = {lang: 'pt-BR'};
#
#             (function() {
#                 var po = document.createElement('script');
#                 po.type = 'text/javascript';
#                 po.async = true;
#                 po.src = 'https://apis.google.com/js/plusone.js';
#                 var s = document.getElementsByTagName('script')[0];
#                 s.parentNode.insertBefore(po, s);
#             })();
#         </script>
#        </li>
#        <li class="btn-twitter">
#         <a class="twitter-share-button" data-lang="pt" href="https://twitter.com/share">
#          Tweetar
#         </a>
#         <script>
#          !function(d, s, id) {
#                 var js, fjs = d.getElementsByTagName(s)[0], p = /^http:/.test(d.location) ? 'http' : 'https';
#                 if (!d.getElementById(id)) {
#                     js = d.createElement(s);
#                     js.id = id;
#                     js.src = p + '://platform.twitter.com/widgets.js';
#                     fjs.parentNode.insertBefore(js, fjs);
#                 }
#             }(document, 'script', 'twitter-wjs');
#         </script>
#        </li>
#       </ul>
#       <nav class="responsive">
#        <ul>
#         <li class="main">
#          <button>
#           <i>
#           </i>
#          </button>
#         </li>
#        </ul>
#       </nav>
#      </div>
#     </div>
#    </header>
#    <div class="container" id="navbar">
#     <div class="clearfix">
#      <nav class="main">
#       <ul>
#        <li class="home light-icon">
#         <a href="index.php">
#          <i>
#          </i>
#          <span>
#           Home
#          </span>
#         </a>
#        </li>
#        <li class="page">
#         <a href="/populacao-dos-estados-brasileiros.php">
#          População dos Estados
#         </a>
#        </li>
#        <li class="page">
#         <a href="/populacao-das-cidades-brasileiras.php">
#          População das Cidades
#         </a>
#        </li>
#        <li class="page">
#         <a href="/bairro-buscar.php">
#          População dos Bairros
#         </a>
#        </li>
#        <li class="page">
#         <a href="/estado-comparar.php">
#          Comparar Estados
#         </a>
#        </li>
#        <li class="page">
#         <a href="/municipio-comparar.php">
#          Comparar Cidades
#         </a>
#        </li>
#        <li class="page">
#         <a href="/bairro-comparar.php">
#          Comparar Bairro
#         </a>
#        </li>
#       </ul>
#       <button>
#        <i>
#        </i>
#       </button>
#      </nav>
#     </div>
#    </div>
#   </div>
#   <div id="content-section">
#    <div class="container">
#     <div class="container-inner">
#      <div class="row">
#       <div class="span8" id="content">
#        <div class="post">
#         <div class="post-main">
#          <div class="post-content">
#           <div class="linha">
#            <h1 class="post-title">
#             Maiores Bairros de Boa Vista
#            </h1>
#            <p class="lead">
#             Segundo o
#             <b>
#              Censo 2010
#             </b>
#             , considerando a população de cada bairro, esta página apresenta a estimativa de comparação de tamanho dos
#             <b>
#              maiores bairros de Boa Vista
#             </b>
#             .
#                                                 Levando em consideração a população de cada bairro.
#            </p>
#           </div>
#           <div class="linha">
#            <h2 class="sub-titulo">
#             <span>
#              O Maior Bairro de
#              <b>
#               Boa Vista
#              </b>
#              em Roraima
#             </span>
#            </h2>
#            <a class="cta arrow" href="#">
#             <span class="ico">
#              <i>
#              </i>
#             </span>
#             <span class="text">
#              <small>
#               Qual é o bairro mais populoso de Boa Vista?
#              </small>
#              Pintolândia com 10.990 hab
#             </span>
#            </a>
#           </div>
#           <div class="linha">
#            <h2 class="sub-titulo">
#             <span>
#              Os 10 Maiores Bairros de Boa Vista
#             </span>
#            </h2>
#            <p>
#             O gráfico a seguir apresenta em ordem de-crescente os 10 maiores bairros de Boa Vista:
#            </p>
#            <div class="conteudo">
#             <script type="text/javascript">
#              google.setOnLoadCallback(draw_popmaiores);
#     function draw_popmaiores() {
#         var data = new google.visualization.DataTable();
#         data.addColumn('string', 'Censo');
#         //Adiciona as colunas
#             data.addColumn('number', 'Pintolândia');
#             data.addColumn('number', 'Senador Hélio Campos');
#             data.addColumn('number', 'Caranã');
#             data.addColumn('number', 'Cambará');
#             data.addColumn('number', 'Buritis');
#             data.addColumn('number', 'Dr. Silvio Leite');
#             data.addColumn('number', 'Santa Luzia');
#             data.addColumn('number', 'Santa Tereza');
#             data.addColumn('number', 'Alvorada');
#             data.addColumn('number', 'Cauamé');
#
#
#
#         data.addRow(["Censo 2010",10990,10010,9931,9488,9305,8849,8777,8118,7914,7480]);
#
#         var options = {title: 'Boa Vista: Os 10 Maiores Bairros', vAxis: {minValue: 0}};
#         var chart = new google.visualization.ColumnChart(document.getElementById('chart_div_popmaiores'));
#         chart.draw(data, options);
#     }
#             </script>
#             <div id="chart_div_popmaiores" style="width: 100%; height: 300px;">
#             </div>
#            </div>
#           </div>
#           <div class="linha">
#            <h2 class="sub-titulo">
#             <span>
#              Análise sobre a população dos maiores bairros de Boa Vista
#             </span>
#            </h2>
#            <div class="conteudo">
#             <div style="float: left; margin-right: 10px; margin-bottom: 10px">
#              <div class="adsense adsense-336x280">
#               <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#               </script>
#               <!-- População - 336x280 -->
#               <ins class="adsbygoogle" data-ad-client="ca-pub-7967827266296075" data-ad-slot="2982381844" style="display:inline-block;width:336px;height:280px">
#               </ins>
#               <script>
#                (adsbygoogle = window.adsbygoogle || []).push({});
#               </script>
#              </div>
#             </div>
#             <p class="lead">
#              O maior bairro de Boa Vista é
#              <a href="/populacao-pintolandia_boa-vista_rr.html">
#               Pintolândia
#              </a>
#              com 10.990 hab.
#
#                                                                                                             Em segundo lugar
#              <a href="/populacao-senador-helio-campos_boa-vista_rr.html">
#               Senador Hélio Campos
#              </a>
#              com 10.010 hab.
#
#                                                                                                             O terceiro maior bairro é
#              <a href="/populacao-carana_boa-vista_rr.html">
#               Caranã
#              </a>
#              com 9.931 hab.
#
#                                                                                                             Em quarto
#              <a href="/populacao-cambara_boa-vista_rr.html">
#               Cambará
#              </a>
#              com 9.488 hab
#
#                                                                                                             e em quinto
#              <a href="/populacao-buritis_boa-vista_rr.html">
#               Buritis
#              </a>
#              com 9.305 hab
#
#                                                     . A seguir, veja a tabela que ilustra essa referência:
#             </p>
#             <div class="clearfix">
#             </div>
#            </div>
#            <div class="conteudo">
#             <table class="zebra" id="tablelista" style="width: 100%">
#              <thead>
#               <tr>
#                <th>
#                 Bairro
#                </th>
#                <th>
#                 População
#                </th>
#               </tr>
#              </thead>
#              <tr>
#               <td>
#                <a href="/populacao-pintolandia_boa-vista_rr.html">
#                 Pintolândia
#                </a>
#               </td>
#               <td>
#                10.990
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <a href="/populacao-senador-helio-campos_boa-vista_rr.html">
#                 Senador Hélio Campos
#                </a>
#               </td>
#               <td>
#                10.010
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <a href="/populacao-carana_boa-vista_rr.html">
#                 Caranã
#                </a>
#               </td>
#               <td>
#                9.931
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <a href="/populacao-cambara_boa-vista_rr.html">
#                 Cambará
#                </a>
#               </td>
#               <td>
#                9.488
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <a href="/populacao-buritis_boa-vista_rr.html">
#                 Buritis
#                </a>
#               </td>
#               <td>
#                9.305
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <a href="/populacao-dr-silvio-leite_boa-vista_rr.html">
#                 Dr. Silvio Leite
#                </a>
#               </td>
#               <td>
#                8.849
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <a href="/populacao-santa-luzia_boa-vista_rr.html">
#                 Santa Luzia
#                </a>
#               </td>
#               <td>
#                8.777
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <a href="/populacao-santa-tereza_boa-vista_rr.html">
#                 Santa Tereza
#                </a>
#               </td>
#               <td>
#                8.118
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <a href="/populacao-alvorada_boa-vista_rr.html">
#                 Alvorada
#                </a>
#               </td>
#               <td>
#                7.914
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <a href="/populacao-cauame_boa-vista_rr.html">
#                 Cauamé
#                </a>
#               </td>
#               <td>
#                7.480
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <a href="/populacao-caimbe_boa-vista_rr.html">
#                 Caimbé
#                </a>
#               </td>
#               <td>
#                7.447
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <a href="/populacao-boa-vista-demais-setores_boa-vista_rr.html">
#                 Boa Vista (demais Setores)
#                </a>
#               </td>
#               <td>
#                7.237
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <a href="/populacao-dr-silvio-botelho_boa-vista_rr.html">
#                 Dr. Silvio Botelho
#                </a>
#               </td>
#               <td>
#                7.188
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <a href="/populacao-pricuma_boa-vista_rr.html">
#                 Pricumã
#                </a>
#               </td>
#               <td>
#                7.051
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <a href="/populacao-tancredo-neves_boa-vista_rr.html">
#                 Tancredo Neves
#                </a>
#               </td>
#               <td>
#                7.007
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <a href="/populacao-joquei-clube_boa-vista_rr.html">
#                 Jóquei Clube
#                </a>
#               </td>
#               <td>
#                6.515
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <a href="/populacao-sao-bento_boa-vista_rr.html">
#                 São Bento
#                </a>
#               </td>
#               <td>
#                6.368
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <a href="/populacao-sao-vicente_boa-vista_rr.html">
#                 São Vicente
#                </a>
#               </td>
#               <td>
#                6.222
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <a href="/populacao-liberdade_boa-vista_rr.html">
#                 Liberdade
#                </a>
#               </td>
#               <td>
#                6.199
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <a href="/populacao-jardim-primavera_boa-vista_rr.html">
#                 Jardim Primavera
#                </a>
#               </td>
#               <td>
#                6.186
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <a href="/populacao-mecejana_boa-vista_rr.html">
#                 Mecejana
#                </a>
#               </td>
#               <td>
#                6.134
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <a href="/populacao-nova-canaa_boa-vista_rr.html">
#                 Nova Canaã
#                </a>
#               </td>
#               <td>
#                6.007
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <a href="/populacao-cidade-satelite_boa-vista_rr.html">
#                 Cidade Satélite
#                </a>
#               </td>
#               <td>
#                5.942
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <a href="/populacao-cinturao-verde_boa-vista_rr.html">
#                 Cinturão Verde
#                </a>
#               </td>
#               <td>
#                5.907
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <a href="/populacao-raiar-do-sol_boa-vista_rr.html">
#                 Raiar de Sol
#                </a>
#               </td>
#               <td>
#                5.863
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <a href="/populacao-nova-cidade_boa-vista_rr.html">
#                 Nova Cidade
#                </a>
#               </td>
#               <td>
#                5.708
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <a href="/populacao-jardim-equatorial_boa-vista_rr.html">
#                 Jardim Equatorial
#                </a>
#               </td>
#               <td>
#                5.594
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <a href="/populacao-centenario_boa-vista_rr.html">
#                 Centenário
#                </a>
#               </td>
#               <td>
#                5.497
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <a href="/populacao-paraviana_boa-vista_rr.html">
#                 Paraviana
#                </a>
#               </td>
#               <td>
#                5.443
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <a href="/populacao-asa-branca_boa-vista_rr.html">
#                 Asa Branca
#                </a>
#               </td>
#               <td>
#                5.256
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <a href="/populacao-centro_boa-vista_rr.html">
#                 Centro
#                </a>
#               </td>
#               <td>
#                5.140
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <a href="/populacao-laura-moreira_boa-vista_rr.html">
#                 Laura Moreira
#                </a>
#               </td>
#               <td>
#                4.992
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <a href="/populacao-aparecida_boa-vista_rr.html">
#                 Aparecida
#                </a>
#               </td>
#               <td>
#                4.860
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <a href="/populacao-treze-de-setembro_boa-vista_rr.html">
#                 Treze de Setembro
#                </a>
#               </td>
#               <td>
#                4.643
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <a href="/populacao-dos-estados_boa-vista_rr.html">
#                 Dos Estados
#                </a>
#               </td>
#               <td>
#                4.639
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <a href="/populacao-jardim-floresta_boa-vista_rr.html">
#                 Jardim Floresta
#                </a>
#               </td>
#               <td>
#                4.546
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <a href="/populacao-professora-araceli-souto-maior_boa-vista_rr.html">
#                 Professora Araceli Souto Maior
#                </a>
#               </td>
#               <td>
#                4.102
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <a href="/populacao-sao-francisco_boa-vista_rr.html">
#                 São Francisco
#                </a>
#               </td>
#               <td>
#                3.992
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <a href="/populacao-uniao_boa-vista_rr.html">
#                 União
#                </a>
#               </td>
#               <td>
#                3.801
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <a href="/populacao-jardim-carana_boa-vista_rr.html">
#                 Jardim Caranã
#                </a>
#               </td>
#               <td>
#                3.495
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <a href="/populacao-aeroporto_boa-vista_rr.html">
#                 Aeroporto
#                </a>
#               </td>
#               <td>
#                3.348
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <a href="/populacao-cacari_boa-vista_rr.html">
#                 Caçari
#                </a>
#               </td>
#               <td>
#                3.254
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <a href="/populacao-bela-vista_boa-vista_rr.html">
#                 Bela Vista
#                </a>
#               </td>
#               <td>
#                3.084
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <a href="/populacao-operario_boa-vista_rr.html">
#                 Operário
#                </a>
#               </td>
#               <td>
#                2.521
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <a href="/populacao-calunga_boa-vista_rr.html">
#                 Calunga
#                </a>
#               </td>
#               <td>
#                2.236
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <a href="/populacao-jardim-tropical_boa-vista_rr.html">
#                 Jardim Tropical
#                </a>
#               </td>
#               <td>
#                2.073
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <a href="/populacao-trinta-e-um-de-marco_boa-vista_rr.html">
#                 Trinta e Um de Março
#                </a>
#               </td>
#               <td>
#                1.631
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <a href="/populacao-5-de-outubro_boa-vista_rr.html">
#                 5 de Outubro
#                </a>
#               </td>
#               <td>
#                1.542
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <a href="/populacao-piscicultura_boa-vista_rr.html">
#                 Piscicultura
#                </a>
#               </td>
#               <td>
#                1.471
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <a href="/populacao-sao-pedro_boa-vista_rr.html">
#                 São Pedro
#                </a>
#               </td>
#               <td>
#                985
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <a href="/populacao-olimpico_boa-vista_rr.html">
#                 Olímpico
#                </a>
#               </td>
#               <td>
#                915
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <a href="/populacao-canarinho_boa-vista_rr.html">
#                 Canarinho
#                </a>
#               </td>
#               <td>
#                710
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <a href="/populacao-governador-aquilino-mota-duarte_boa-vista_rr.html">
#                 Governador Aquilino Mota Duarte
#                </a>
#               </td>
#               <td>
#                519
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <a href="/populacao-murilo-teixeira-cidade_boa-vista_rr.html">
#                 Murilo Teixeira Cidade
#                </a>
#               </td>
#               <td>
#                112
#               </td>
#              </tr>
#              <tr>
#               <td>
#                <a href="/populacao-doutor-airton-rocha_boa-vista_rr.html">
#                 Doutor Airton Rocha
#                </a>
#               </td>
#               <td>
#                69
#               </td>
#              </tr>
#             </table>
#            </div>
#           </div>
#           <div class="linha">
#            <div class="ad-right">
#             <div class="ad">
#              <div class="adsense adsense-300x250">
#               <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#               </script>
#               <!-- População - 300x250 -->
#               <ins class="adsbygoogle" data-ad-client="ca-pub-7967827266296075" data-ad-slot="9028915443" style="display:inline-block;width:300px;height:250px">
#               </ins>
#               <script>
#                (adsbygoogle = window.adsbygoogle || []).push({});
#               </script>
#              </div>
#             </div>
#             <div class="conteudo">
#              <h4>
#               Veja Também
#              </h4>
#              <ul>
#               <li>
#                <a href="/populacao-boa-vista_rr.html">
#                 <span class="ico">
#                  <i>
#                  </i>
#                 </span>
#                 População de Boa Vista
#                </a>
#               </li>
#               <li>
#                <a href="/os-maiores-bairros-boa-vista_rr.html">
#                 <span class="ico">
#                  <i>
#                  </i>
#                 </span>
#                 Os maiores bairros de Boa Vista
#                </a>
#               </li>
#               <li>
#                <a href="/bairros-com-mais-idosos-boa-vista_rr.html">
#                 <span class="ico">
#                  <i>
#                  </i>
#                 </span>
#                 Bairros com mais idosos Boa Vista
#                </a>
#               </li>
#               <li>
#                <a href="/bairros-com-mais-jovens-boa-vista_rr.html">
#                 <span class="ico">
#                  <i>
#                  </i>
#                 </span>
#                 Bairros com mais jovens Boa Vista
#                </a>
#               </li>
#               <li>
#                <a href="/bairros-com-mais-criancas-boa-vista_rr.html">
#                 <span class="ico">
#                  <i>
#                  </i>
#                 </span>
#                 Bairros com mais crianças Boa Vista
#                </a>
#               </li>
#               <li>
#                <a href="/o-melhor-bairro-para-encontar-uma-namorada-boa-vista_rr.html">
#                 <span class="ico">
#                  <i>
#                  </i>
#                 </span>
#                 O melhor bairro para encontrar uma namorada em Boa Vista
#                </a>
#               </li>
#               <li>
#                <a href="/o-melhor-bairro-para-encontar-um-marido-boa-vista_rr.html">
#                 <span class="ico">
#                  <i>
#                  </i>
#                 </span>
#                 O melhor bairro para encontrar um marido em Boa Vista
#                </a>
#               </li>
#              </ul>
#             </div>
#             <div class="clearfix">
#             </div>
#            </div>
#           </div>
#           <div id="disqus_thread">
#           </div>
#           <script type="text/javascript">
#            /* * * CONFIGURATION VARIABLES: EDIT BEFORE PASTING INTO YOUR WEBPAGE * * */
#     var disqus_shortname = 'populao'; // required: replace example with your forum shortname
#
#     /* * * DON'T EDIT BELOW THIS LINE * * */
#     (function() {
#         var dsq = document.createElement('script');
#         dsq.type = 'text/javascript';
#         dsq.async = true;
#         dsq.src = '//' + disqus_shortname + '.disqus.com/embed.js';
#         (document.getElementsByTagName('head')[0] || document.getElementsByTagName('body')[0]).appendChild(dsq);
#     })();
#           </script>
#           <noscript>
#            Please enable JavaScript to view the
#            <a href="http://disqus.com/?ref_noscript">
#             comments powered by Disqus.
#            </a>
#           </noscript>
#           <a class="dsq-brlink" href="http://disqus.com">
#            comments powered by
#            <span class="logo-disqus">
#             Disqus
#            </span>
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#       <aside class="span4">
#        <div id="sidebar">
#         <ul id="widgets">
#          <li class="widget">
#           <div class="row-fluid">
#            <div class="span6">
#             <div class="adsense adsense-300x250">
#              <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#              </script>
#              <!-- População - 300x250 -->
#              <ins class="adsbygoogle" data-ad-client="ca-pub-7967827266296075" data-ad-slot="9028915443" style="display:inline-block;width:300px;height:250px">
#              </ins>
#              <script>
#               (adsbygoogle = window.adsbygoogle || []).push({});
#              </script>
#             </div>
#            </div>
#           </div>
#          </li>
#          <li class="widget" id="categories-widget">
#           <h3>
#            <span>
#             Bairros de
#            </span>
#           </h3>
#           <div class="widget-content lista-bairros tag_cloud_cidade">
#            <input id="lista-bairros-input" placeholder="Buscar..." type="text"/>
#            <ul id="lista-bairros-ul">
#             <li>
#              <a href="/populacao-pintolandia_boa-vista_rr.html">
#               <span class="ico">
#                <i>
#                </i>
#               </span>
#               Pintolândia
#              </a>
#             </li>
#             <li>
#              <a href="/populacao-senador-helio-campos_boa-vista_rr.html">
#               <span class="ico">
#                <i>
#                </i>
#               </span>
#               Senador Hélio Campos
#              </a>
#             </li>
#             <li>
#              <a href="/populacao-carana_boa-vista_rr.html">
#               <span class="ico">
#                <i>
#                </i>
#               </span>
#               Caranã
#              </a>
#             </li>
#             <li>
#              <a href="/populacao-cambara_boa-vista_rr.html">
#               <span class="ico">
#                <i>
#                </i>
#               </span>
#               Cambará
#              </a>
#             </li>
#             <li>
#              <a href="/populacao-buritis_boa-vista_rr.html">
#               <span class="ico">
#                <i>
#                </i>
#               </span>
#               Buritis
#              </a>
#             </li>
#             <li>
#              <a href="/populacao-dr-silvio-leite_boa-vista_rr.html">
#               <span class="ico">
#                <i>
#                </i>
#               </span>
#               Dr. Silvio Leite
#              </a>
#             </li>
#             <li>
#              <a href="/populacao-santa-luzia_boa-vista_rr.html">
#               <span class="ico">
#                <i>
#                </i>
#               </span>
#               Santa Luzia
#              </a>
#             </li>
#             <li>
#              <a href="/populacao-santa-tereza_boa-vista_rr.html">
#               <span class="ico">
#                <i>
#                </i>
#               </span>
#               Santa Tereza
#              </a>
#             </li>
#             <li>
#              <a href="/populacao-alvorada_boa-vista_rr.html">
#               <span class="ico">
#                <i>
#                </i>
#               </span>
#               Alvorada
#              </a>
#             </li>
#             <li>
#              <a href="/populacao-cauame_boa-vista_rr.html">
#               <span class="ico">
#                <i>
#                </i>
#               </span>
#               Cauamé
#              </a>
#             </li>
#             <li>
#              <a href="/populacao-caimbe_boa-vista_rr.html">
#               <span class="ico">
#                <i>
#                </i>
#               </span>
#               Caimbé
#              </a>
#             </li>
#             <li>
#              <a href="/populacao-boa-vista-demais-setores_boa-vista_rr.html">
#               <span class="ico">
#                <i>
#                </i>
#               </span>
#               Boa Vista (demais Setores)
#              </a>
#             </li>
#             <li>
#              <a href="/populacao-dr-silvio-botelho_boa-vista_rr.html">
#               <span class="ico">
#                <i>
#                </i>
#               </span>
#               Dr. Silvio Botelho
#              </a>
#             </li>
#             <li>
#              <a href="/populacao-pricuma_boa-vista_rr.html">
#               <span class="ico">
#                <i>
#                </i>
#               </span>
#               Pricumã
#              </a>
#             </li>
#             <li>
#              <a href="/populacao-tancredo-neves_boa-vista_rr.html">
#               <span class="ico">
#                <i>
#                </i>
#               </span>
#               Tancredo Neves
#              </a>
#             </li>
#             <li>
#              <a href="/populacao-joquei-clube_boa-vista_rr.html">
#               <span class="ico">
#                <i>
#                </i>
#               </span>
#               Jóquei Clube
#              </a>
#             </li>
#             <li>
#              <a href="/populacao-sao-bento_boa-vista_rr.html">
#               <span class="ico">
#                <i>
#                </i>
#               </span>
#               São Bento
#              </a>
#             </li>
#             <li>
#              <a href="/populacao-sao-vicente_boa-vista_rr.html">
#               <span class="ico">
#                <i>
#                </i>
#               </span>
#               São Vicente
#              </a>
#             </li>
#             <li>
#              <a href="/populacao-liberdade_boa-vista_rr.html">
#               <span class="ico">
#                <i>
#                </i>
#               </span>
#               Liberdade
#              </a>
#             </li>
#             <li>
#              <a href="/populacao-jardim-primavera_boa-vista_rr.html">
#               <span class="ico">
#                <i>
#                </i>
#               </span>
#               Jardim Primavera
#              </a>
#             </li>
#             <li>
#              <a href="/populacao-mecejana_boa-vista_rr.html">
#               <span class="ico">
#                <i>
#                </i>
#               </span>
#               Mecejana
#              </a>
#             </li>
#             <li>
#              <a href="/populacao-nova-canaa_boa-vista_rr.html">
#               <span class="ico">
#                <i>
#                </i>
#               </span>
#               Nova Canaã
#              </a>
#             </li>
#             <li>
#              <a href="/populacao-cidade-satelite_boa-vista_rr.html">
#               <span class="ico">
#                <i>
#                </i>
#               </span>
#               Cidade Satélite
#              </a>
#             </li>
#             <li>
#              <a href="/populacao-cinturao-verde_boa-vista_rr.html">
#               <span class="ico">
#                <i>
#                </i>
#               </span>
#               Cinturão Verde
#              </a>
#             </li>
#             <li>
#              <a href="/populacao-raiar-do-sol_boa-vista_rr.html">
#               <span class="ico">
#                <i>
#                </i>
#               </span>
#               Raiar de Sol
#              </a>
#             </li>
#             <li>
#              <a href="/populacao-nova-cidade_boa-vista_rr.html">
#               <span class="ico">
#                <i>
#                </i>
#               </span>
#               Nova Cidade
#              </a>
#             </li>
#             <li>
#              <a href="/populacao-jardim-equatorial_boa-vista_rr.html">
#               <span class="ico">
#                <i>
#                </i>
#               </span>
#               Jardim Equatorial
#              </a>
#             </li>
#             <li>
#              <a href="/populacao-centenario_boa-vista_rr.html">
#               <span class="ico">
#                <i>
#                </i>
#               </span>
#               Centenário
#              </a>
#             </li>
#             <li>
#              <a href="/populacao-paraviana_boa-vista_rr.html">
#               <span class="ico">
#                <i>
#                </i>
#               </span>
#               Paraviana
#              </a>
#             </li>
#             <li>
#              <a href="/populacao-asa-branca_boa-vista_rr.html">
#               <span class="ico">
#                <i>
#                </i>
#               </span>
#               Asa Branca
#              </a>
#             </li>
#             <li>
#              <a href="/populacao-centro_boa-vista_rr.html">
#               <span class="ico">
#                <i>
#                </i>
#               </span>
#               Centro
#              </a>
#             </li>
#             <li>
#              <a href="/populacao-laura-moreira_boa-vista_rr.html">
#               <span class="ico">
#                <i>
#                </i>
#               </span>
#               Laura Moreira
#              </a>
#             </li>
#             <li>
#              <a href="/populacao-aparecida_boa-vista_rr.html">
#               <span class="ico">
#                <i>
#                </i>
#               </span>
#               Aparecida
#              </a>
#             </li>
#             <li>
#              <a href="/populacao-treze-de-setembro_boa-vista_rr.html">
#               <span class="ico">
#                <i>
#                </i>
#               </span>
#               Treze de Setembro
#              </a>
#             </li>
#             <li>
#              <a href="/populacao-dos-estados_boa-vista_rr.html">
#               <span class="ico">
#                <i>
#                </i>
#               </span>
#               Dos Estados
#              </a>
#             </li>
#             <li>
#              <a href="/populacao-jardim-floresta_boa-vista_rr.html">
#               <span class="ico">
#                <i>
#                </i>
#               </span>
#               Jardim Floresta
#              </a>
#             </li>
#             <li>
#              <a href="/populacao-professora-araceli-souto-maior_boa-vista_rr.html">
#               <span class="ico">
#                <i>
#                </i>
#               </span>
#               Professora Araceli Souto Maior
#              </a>
#             </li>
#             <li>
#              <a href="/populacao-sao-francisco_boa-vista_rr.html">
#               <span class="ico">
#                <i>
#                </i>
#               </span>
#               São Francisco
#              </a>
#             </li>
#             <li>
#              <a href="/populacao-uniao_boa-vista_rr.html">
#               <span class="ico">
#                <i>
#                </i>
#               </span>
#               União
#              </a>
#             </li>
#             <li>
#              <a href="/populacao-jardim-carana_boa-vista_rr.html">
#               <span class="ico">
#                <i>
#                </i>
#               </span>
#               Jardim Caranã
#              </a>
#             </li>
#             <li>
#              <a href="/populacao-aeroporto_boa-vista_rr.html">
#               <span class="ico">
#                <i>
#                </i>
#               </span>
#               Aeroporto
#              </a>
#             </li>
#             <li>
#              <a href="/populacao-cacari_boa-vista_rr.html">
#               <span class="ico">
#                <i>
#                </i>
#               </span>
#               Caçari
#              </a>
#             </li>
#             <li>
#              <a href="/populacao-bela-vista_boa-vista_rr.html">
#               <span class="ico">
#                <i>
#                </i>
#               </span>
#               Bela Vista
#              </a>
#             </li>
#             <li>
#              <a href="/populacao-operario_boa-vista_rr.html">
#               <span class="ico">
#                <i>
#                </i>
#               </span>
#               Operário
#              </a>
#             </li>
#             <li>
#              <a href="/populacao-calunga_boa-vista_rr.html">
#               <span class="ico">
#                <i>
#                </i>
#               </span>
#               Calunga
#              </a>
#             </li>
#             <li>
#              <a href="/populacao-jardim-tropical_boa-vista_rr.html">
#               <span class="ico">
#                <i>
#                </i>
#               </span>
#               Jardim Tropical
#              </a>
#             </li>
#             <li>
#              <a href="/populacao-trinta-e-um-de-marco_boa-vista_rr.html">
#               <span class="ico">
#                <i>
#                </i>
#               </span>
#               Trinta e Um de Março
#              </a>
#             </li>
#             <li>
#              <a href="/populacao-5-de-outubro_boa-vista_rr.html">
#               <span class="ico">
#                <i>
#                </i>
#               </span>
#               5 de Outubro
#              </a>
#             </li>
#             <li>
#              <a href="/populacao-piscicultura_boa-vista_rr.html">
#               <span class="ico">
#                <i>
#                </i>
#               </span>
#               Piscicultura
#              </a>
#             </li>
#             <li>
#              <a href="/populacao-sao-pedro_boa-vista_rr.html">
#               <span class="ico">
#                <i>
#                </i>
#               </span>
#               São Pedro
#              </a>
#             </li>
#             <li>
#              <a href="/populacao-olimpico_boa-vista_rr.html">
#               <span class="ico">
#                <i>
#                </i>
#               </span>
#               Olímpico
#              </a>
#             </li>
#             <li>
#              <a href="/populacao-canarinho_boa-vista_rr.html">
#               <span class="ico">
#                <i>
#                </i>
#               </span>
#               Canarinho
#              </a>
#             </li>
#             <li>
#              <a href="/populacao-governador-aquilino-mota-duarte_boa-vista_rr.html">
#               <span class="ico">
#                <i>
#                </i>
#               </span>
#               Governador Aquilino Mota Duarte
#              </a>
#             </li>
#             <li>
#              <a href="/populacao-murilo-teixeira-cidade_boa-vista_rr.html">
#               <span class="ico">
#                <i>
#                </i>
#               </span>
#               Murilo Teixeira Cidade
#              </a>
#             </li>
#             <li>
#              <a href="/populacao-doutor-airton-rocha_boa-vista_rr.html">
#               <span class="ico">
#                <i>
#                </i>
#               </span>
#               Doutor Airton Rocha
#              </a>
#             </li>
#            </ul>
#           </div>
#          </li>
#          <li class="widget" id="description-widget">
#           <h3>
#            <span>
#             Sobre População.net.br
#            </span>
#           </h3>
#           <div class="widget-content">
#            <p>
#             O portal
#             <a href="/">
#              População.net.br
#             </a>
#             busca apresentar
#                         de forma clara e intuitiva informações sobre a população
#                         de bairros, cidades, estados e países. São apresentados
#                         gráficos que tornam visual as dimensões de população apresentadas
#                         pelos resultados de
#             <a href="/populacao-dos-estados-brasileiros.php">
#              população censo 2010
#             </a>
#             .
#            </p>
#           </div>
#          </li>
#         </ul>
#         <div class="sidebar-bottom">
#          <p>
#           © 2013 - População.net.br o maior portal de população do brasil.
#          </p>
#         </div>
#        </div>
#       </aside>
#      </div>
#     </div>
#    </div>
#   </div>
#   <a class="back-to-top light-icon" href="#top">
#    <i>
#    </i>
#   </a>
#   <!-- BACK TO TOP : end -->
#   <var id="screen-width">
#   </var>
#   <script>
#    $(document).ready(function() {
#                 //Current
#                 $("nav.main").find("li a[href='/maires-bairros.php']").addClass('current');
#
#             });
#   </script>
#  </body>
# </html>

# %%
tabela = soup.find_all('td')

# %%
len(tabela)
# Out:
# 110

# %%
dic = {}
for i in range (0,len(tabela),2):
    dic[tabela[i].get_text()] = tabela[i+1].get_text()

# %%
dic
# Out:
# {'Pintolândia': '10.990',
#  'Senador Hélio Campos': '10.010',
#  'Caranã': '9.931',
#  'Cambará': '9.488',
#  'Buritis': '9.305',
#  'Dr. Silvio Leite': '8.849',
#  'Santa Luzia': '8.777',
#  'Santa Tereza': '8.118',
#  'Alvorada': '7.914',
#  'Cauamé': '7.480',
#  'Caimbé': '7.447',
#  'Boa Vista (demais Setores)': '7.237',
#  'Dr. Silvio Botelho': '7.188',
#  'Pricumã': '7.051',
#  'Tancredo Neves': '7.007',
#  'Jóquei Clube': '6.515',
#  'São Bento': '6.368',
#  'São Vicente': '6.222',
#  'Liberdade': '6.199',
#  'Jardim Primavera': '6.186',
#  'Mecejana': '6.134',
#  'Nova Canaã': '6.007',
#  'Cidade Satélite': '5.942',
#  'Cinturão Verde': '5.907',
#  'Raiar de Sol': '5.863',
#  'Nova Cidade': '5.708',
#  'Jardim Equatorial': '5.594',
#  'Centenário': '5.497',
#  'Paraviana': '5.443',
#  'Asa Branca': '5.256',
#  'Centro': '5.140',
#  'Laura Moreira': '4.992',
#  'Aparecida': '4.860',
#  'Treze de Setembro': '4.643',
#  'Dos Estados': '4.639',
#  'Jardim Floresta': '4.546',
#  'Professora Araceli Souto Maior': '4.102',
#  'São Francisco': '3.992',
#  'União': '3.801',
#  'Jardim Caranã': '3.495',
#  'Aeroporto': '3.348',
#  'Caçari': '3.254',
#  'Bela Vista': '3.084',
#  'Operário': '2.521',
#  'Calunga': '2.236',
#  'Jardim Tropical': '2.073',
#  'Trinta e Um de Março': '1.631',
#  '5 de Outubro': '1.542',
#  'Piscicultura': '1.471',
#  'São Pedro': '985',
#  'Olímpico': '915',
#  'Canarinho': '710',
#  'Governador Aquilino Mota Duarte': '519',
#  'Murilo Teixeira Cidade': '112',
#  'Doutor Airton Rocha': '69'}

# %%
print(location.raw['address']['suburb'])
# Out:
# Centro

# %%
dic[location.raw['address']['suburb']]
# Out:
# '5.140'
